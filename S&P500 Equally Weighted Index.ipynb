# %%
import numpy as np 
import pandas as pd 
import requests 
import xlsxwriter 
import math

# %%
stocks = pd.read_csv('sp_500_stocks.csv')
print(stocks)
# Out:
#     Ticker
# 0        A
# 1      AAL
# 2      AAP
# 3     AAPL
# 4     ABBV
# ..     ...
# 491    YUM
# 492    ZBH
# 493   ZBRA
# 494   ZION
# 495    ZTS
#
# [496 rows x 1 columns]

# %%
symbol='AAPL'
api_url = f'https://cloud.iexapis.com/stable/stock/{symbol}/quote/?token=sk_f35e72cbeb9d4cc09281640e5f1f899a'
data = requests.get(api_url).json()
data
# Out:
# {'avgTotalVolume': 54011435,
#  'calculationPrice': 'close',
#  'change': -1.08,
#  'changePercent': -0.00555,
#  'close': None,
#  'closeSource': 'official',
#  'closeTime': None,
#  'companyName': 'Apple Inc',
#  'currency': 'USD',
#  'delayedPrice': None,
#  'delayedPriceTime': None,
#  'extendedChange': None,
#  'extendedChangePercent': None,
#  'extendedPrice': None,
#  'extendedPriceTime': None,
#  'high': None,
#  'highSource': None,
#  'highTime': None,
#  'iexAskPrice': 0,
#  'iexAskSize': 0,
#  'iexBidPrice': 0,
#  'iexBidSize': 0,
#  'iexClose': 193.59,
#  'iexCloseTime': 1703278799420,
#  'iexLastUpdated': 1703278799420,
#  'iexMarketPercent': 0.021553008554338584,
#  'iexOpen': 195.165,
#  'iexOpenTime': 1703255400093,
#  'iexRealtimePrice': 193.59,
#  'iexRealtimeSize': 249,
#  'iexVolume': 800685,
#  'lastTradeTime': 1703278799743,
#  'latestPrice': 193.6,
#  'latestSource': 'Close',
#  'latestTime': 'December 22, 2023',
#  'latestUpdate': 1703278800223,
# ...

# %%
price = data['latestPrice']
market_cap = data['marketCap']
print(market_cap)
# Out:
# 3011012787200

# %%
my_columns = ['Ticker','Stock Price','Market Capitalization', 'Number of Shares to Buy']
final_dataframe= pd.DataFrame(columns= my_columns)
final_dataframe
# Out:
# Empty DataFrame
# Columns: [Ticker, Stock Price, Market Capitalization, Number of Shares to Buy]
# Index: []

# %%
final_dataframe.append(
    pd.Series(
    [
        symbol,
        price,
        market_cap,
        'N/A'
    ],
    index=my_columns),
    ignore_index=True
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17472\1259939316.py in ?()
# ----> 1 final_dataframe.append(
#       2     pd.Series(
#       3     [
#       4         symbol,
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
my_columns = ['Tickers', 'Price', 'Market Cap', 'Number of Shares to Buy']
final_dataframe = pd.DataFrame(columns=my_columns)

data_list = []

for symbol in stocks['Ticker']:
    api_url = f'https://cloud.iexapis.com/stable/stock/{symbol}/quote/?token=sk_f35e72cbeb9d4cc09281640e5f1f899a'
    data = requests.get(api_url).json()

    data_list.append([
        symbol,
        data['latestPrice'],
        data['marketCap'],
        'N/A'
    ])

final_dataframe = pd.concat([final_dataframe, pd.DataFrame(data_list, columns=my_columns)], ignore_index=True)

# Display the resulting DataFrame
print(final_dataframe)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 8
#       6 for symbol in stocks['Ticker']:
#       7     api_url = f'https://cloud.iexapis.com/stable/stock/{symbol}/quote/?token=sk_f35e72cbeb9d4cc09281640e5f1f899a'
# ----> 8     data = requests.get(api_url).json()
#      10     data_list.append([
#      11         symbol,
#      12         data['latestPrice'],
#      13         data['marketCap'],
#      14         'N/A'
#      15     ])
#      17 final_dataframe = pd.concat([final_dataframe, pd.DataFrame(data_list, columns=my_columns)], ignore_index=True)
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
# ...

# %%
#final_dataframe
print(data)
# Out:
# {'avgTotalVolume': 5989797, 'calculationPrice': 'tops', 'change': 0.14, 'changePercent': 0.00091, 'close': None, 'closeSource': 'official', 'closeTime': None, 'companyName': 'Abbvie Inc', 'currency': 'USD', 'delayedPrice': None, 'delayedPriceTime': None, 'extendedChange': None, 'extendedChangePercent': None, 'extendedPrice': None, 'extendedPriceTime': None, 'high': None, 'highSource': 'IEX real time price', 'highTime': 1703082870955, 'iexAskPrice': 153.76, 'iexAskSize': 100, 'iexBidPrice': 152.78, 'iexBidSize': 142, 'iexClose': 153.74, 'iexCloseTime': 1703101438913, 'iexLastUpdated': 1703101438913, 'iexMarketPercent': 0.03557532248671659, 'iexOpen': 153.81, 'iexOpenTime': 1703082623735, 'iexRealtimePrice': 153.74, 'iexRealtimeSize': 100, 'iexVolume': 62127, 'lastTradeTime': 1703101438913, 'latestPrice': 153.74, 'latestSource': 'IEX real time price', 'latestTime': '2:43:58 PM', 'latestUpdate': 1703101438913, 'latestVolume': None, 'low': None, 'lowSource': '15 minute delayed price', 'l
# ...

# %%
def chunks(lst, n):
    """Yield successive n-sized chunks from lst."""
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# %%
import pandas as pd
import requests

# Assuming you have defined my_columns, stocks, and chunks earlier
my_columns = ['Tickers', 'Price', 'Market Cap', 'Number of Shares to Buy']

symbol_groups = list(chunks(stocks['Ticker'], 100))
symbol_strings = [','.join(symbol_group) for symbol_group in symbol_groups]

final_dataframe = pd.DataFrame(columns=my_columns)
list_corrected = list(data.keys())
data_list = []

for symbol_string in symbol_strings:
    batch_api_call_url = f'https://cloud.iexapis.com/stable/stock/market/batch/?types=quote&symbols={symbol_string}&token=sk_f35e72cbeb9d4cc09281640e5f1f899a'
    data = requests.get(batch_api_call_url).json()

    for symbol in symbol_string.split(','):
                data_list.append([
                    symbol,
                    data[symbol]['quote']['latestPrice'],
                    data[symbol]['quote']['marketCap'],
                    'N/A'
                ])

final_dataframe = pd.concat([final_dataframe, pd.DataFrame(data_list, columns=my_columns)], ignore_index=True)

# Display the resulting DataFrame
final_dataframe
# Out:
#     Tickers   Price    Market Cap Number of Shares to Buy
# 0         A  139.57  4.089458e+10                     N/A
# 1       AAL   14.31  9.352165e+09                     N/A
# 2       AAP   61.25  3.644497e+09                     N/A
# 3      AAPL  193.60  3.011013e+12                     N/A
# 4      ABBV  154.94  2.735524e+11                     N/A
# ..      ...     ...           ...                     ...
# 491     YUM  130.00  3.644007e+10                     N/A
# 492     ZBH  120.56  2.519471e+10                     N/A
# 493    ZBRA  269.41  1.383679e+10                     N/A
# 494    ZION   44.00  6.518547e+09                     N/A
# 495     ZTS  194.98  8.951799e+10                     N/A
#
# [496 rows x 4 columns]

# %%
portfolio_size = input("Enter the size of your portfolio ")

try:
    val = float(portfolio_size)
except:
    print('Please Enter a value')
    portfolio_size = input("Enter the size of your portfolio: ")
# Out:
# Enter the size of your portfolio1000000

# %%
position_size = val*1/len(final_dataframe.index)
for i in range(0,len(final_dataframe.index)):
    final_dataframe.loc[i, 'Number of Shares to Buy'] = math.floor(position_size/final_dataframe.loc[i, 'Price'])
final_dataframe

#final_dataframe
# Out:
#     Tickers   Price    Market Cap Number of Shares to Buy
# 0         A  139.57  4.089458e+10                      14
# 1       AAL   14.31  9.352165e+09                     140
# 2       AAP   61.25  3.644497e+09                      32
# 3      AAPL  193.60  3.011013e+12                      10
# 4      ABBV  154.94  2.735524e+11                      13
# ..      ...     ...           ...                     ...
# 491     YUM  130.00  3.644007e+10                      15
# 492     ZBH  120.56  2.519471e+10                      16
# 493    ZBRA  269.41  1.383679e+10                       7
# 494    ZION   44.00  6.518547e+09                      45
# 495     ZTS  194.98  8.951799e+10                      10
#
# [496 rows x 4 columns]

# %%
#Transfering in Excel
writer = pd.ExcelWriter('Recommended trades.xlsx', engine = 'xlsxwriter')
final_dataframe.to_excel(writer, 'Recommended Trades',index = False)
background_color ='#0a0a23' 
font_color = '#ffffff'

string_format = writer.book.add_format(
        {
            'font_color': font_color,
            'bg_color': background_color,
            'border': 1
        }
    )


dollar_format = writer.book.add_format(
        {
            'num_format':'$0.00',
            'font_color': font_color,
            'bg_color': background_color,
            'border': 1
        }
    )

integer_format = writer.book.add_format(
        {
            'num_format':'0',
            'font_color': font_color,
            'bg_color': background_color,
            'border': 1
        }
    )

# %%
column_formats = { 
                    'A': ['Ticker', string_format],
                    'B': ['Price', dollar_format],
                    'C': ['Market Capitalization', dollar_format],
                    'D': ['Number of Shares to Buy', integer_format]
                    }

for column in column_formats.keys():
    writer.sheets['Recommended Trades'].set_column(f'{column}:{column}', 20, column_formats[column][1])
    writer.sheets['Recommended Trades'].write(f'{column}1', column_formats[column][0], string_format)

# %%
writer.close()
